# %% [markdown]
# # New DFs

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/edwin/Repositories/Data Science/Scholarships Project/app/final_df.csv").iloc[:,1:]
df.sort_values(["ID"],ascending=False).head()
# Out:
#         ID                                                URL  \
# 500   2473  https://www.mastersportal.com/scholarships/777...
# 1732  2472  https://www.mastersportal.com/scholarships/189...
# 830   2471  https://www.mastersportal.com/scholarships/816...
# 1268  2470  https://www.mastersportal.com/scholarships/313...
# 1605  2469  https://www.mastersportal.com/scholarships/695...
#
#                                                   About      Scholarship_Type  \
# 500   University of Leicester can support you financ...  Merit and need based
# 1732  University of Padua can support you financiall...  Merit and need based
# 830   University of Sheffield can support you financ...           Merit based
# 1268  AUC offers financial assistance to study abroa...           Merit based
# 1605  Bio-Techne can support you financially if you ...           Merit based
#
#      Number_of_Scholarships                             Grant  \
# ...

# %%
new_df=pd.read_excel("new scholarships.xlsx")
new_df.head()
# Out:
#      ID                                                URL  \
# 0  2474  https://www.lboro.ac.uk/study/undergraduate/fe...
# 1  2475            http://www.masterbiomolbiomed.unican.es
# 2  2476  https://www.sheffield.ac.uk/international/fees...
#
#                                                About      Scholarship_Type  \
# 0  The bursary is aimed at supporting women wishi...  Merit and Need Based
# 1  Official Master’s Degree in Molecular Biology ...  Merit and Need Based
# 2  The International Postgraduate Taught Merit Sc...           Merit Based
#
#   Number_of_Scholarships                               Grant  \
# 0               Multiple                      £1000 per year
# 1                    One  50% tuition, €900/month for living
# 2               Multiple        £10,000 towards tuition fees
#
#                                 Scholarship_Coverage  \
# 0  Annual payment for each year of the program (e...
# 1  50% of the tuition fees, round-trip ticket, an...
# ...

# %%
final_df=pd.concat([df,new_df])
final_df.head()
# Out:
#      ID                                                URL  \
# 0    44  https://www.mastersportal.com/scholarships/848...
# 1   944  https://www.mastersportal.com/scholarships/861...
# 2  2020  https://www.mastersportal.com/scholarships/288...
# 3    37  https://www.mastersportal.com/scholarships/857...
# 4   575  https://www.mastersportal.com/scholarships/101...
#
#                                                About      Scholarship_Type  \
# 0  University of Barcelona offers grants and supp...            Need based
# 1  At the University of Newcastle, they are proud...           Merit based
# 2  Beijing Government Scholarship for Internation...           Merit based
# 3  At the University of Newcastle, they are proud...           Merit based
# 4  At Ulster University, there are different type...  Merit and need based
#
#   Number_of_Scholarships                                              Grant  \
# 0               Multiple                     Full or partial tuition waiver
# ...

# %%
final_df['User_Filter']=None

# %%
final_df[final_df['ID'].isin({2474,2475,2476})]
# Out:
#      ID                                                URL  \
# 0  2474  https://www.lboro.ac.uk/study/undergraduate/fe...
# 1  2475            http://www.masterbiomolbiomed.unican.es
# 2  2476  https://www.sheffield.ac.uk/international/fees...
#
#                                                About      Scholarship_Type  \
# 0  The bursary is aimed at supporting women wishi...  Merit and Need Based
# 1  Official Master’s Degree in Molecular Biology ...  Merit and Need Based
# 2  The International Postgraduate Taught Merit Sc...           Merit Based
#
#   Number_of_Scholarships                               Grant  \
# 0               Multiple                      £1000 per year
# 1                    One  50% tuition, €900/month for living
# 2               Multiple        £10,000 towards tuition fees
#
#                                 Scholarship_Coverage  \
# 0  Annual payment for each year of the program (e...
# 1  50% of the tuition fees, round-trip ticket, an...
# ...

# %%
final_df.loc[final_df['ID'] == 2474, 'User_Filter'] = ['Carolina']
final_df.loc[final_df['ID'] == 2475, 'User_Filter'] = ['Carolina']
final_df.loc[final_df['ID'] == 2476, 'User_Filter'] = ['Carolina']

# %%
final_df[final_df['ID'].isin({2473,2474,2475,2476})]
# Out:
#        ID                                                URL  \
# 500  2473  https://www.mastersportal.com/scholarships/777...
# 0    2474  https://www.lboro.ac.uk/study/undergraduate/fe...
# 1    2475            http://www.masterbiomolbiomed.unican.es
# 2    2476  https://www.sheffield.ac.uk/international/fees...
#
#                                                  About      Scholarship_Type  \
# 500  University of Leicester can support you financ...  Merit and need based
# 0    The bursary is aimed at supporting women wishi...  Merit and Need Based
# 1    Official Master’s Degree in Molecular Biology ...  Merit and Need Based
# 2    The International Postgraduate Taught Merit Sc...           Merit Based
#
#     Number_of_Scholarships                               Grant  \
# 500               Multiple              Financial contribution
# 0                 Multiple                      £1000 per year
# 1                      One  50% tuition, €900/month for living
# ...

# %%
final_df[final_df['About'].str.contains("Chevening")]
# Out:
#        ID                                                URL  \
# 28      4  https://www.mastersportal.com/scholarships/910...
# 84   1550  https://www.mastersportal.com/scholarships/188...
# 101    75  https://www.mastersportal.com/scholarships/394...
# 181  1527  https://www.mastersportal.com/scholarships/676...
# 351    74  https://www.mastersportal.com/scholarships/159...
#
#                                                  About      Scholarship_Type  \
# 28   Chevening is the UK Government’s international...           Merit based
# 84   Fully-funded scholarships to undertake any mas...           Merit based
# 101  Loughborough University is offering up to 30 f...           Merit based
# 181  Chevening is the UK government’s international...  Merit and need based
# 351  Chevening Scholarships enable outstanding emer...           Merit based
#
#     Number_of_Scholarships                                       Grant  \
# ...

# %%
final_df.loc[final_df['ID'] == 4, 'User_Filter'] = ['Carolina']
final_df.loc[final_df['ID'] == 1550, 'User_Filter'] = ['Carolina']
final_df.loc[final_df['ID'] == 75, 'User_Filter'] = ['Carolina']
final_df.loc[final_df['ID'] == 1527, 'User_Filter'] = ['Carolina']
final_df.loc[final_df['ID'] == 74, 'User_Filter'] = ['Carolina']

# %%
final_df.to_csv("final_df.csv")
